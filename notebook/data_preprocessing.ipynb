# %%
# Import necessary libraries
import sys
sys.path.append('../scripts')

from data_preprocessing import DataPreprocessing

# %%
# Define the assets and time range
tickers = ['TSLA', 'BND', 'SPY']
start_date = '2015-01-01'
end_date = '2024-10-31'

# %% [markdown]
# Initialize the DataPreprocessing class

# %%
dp = DataPreprocessing(tickers, start_date, end_date)

# %% [markdown]
# Fetch Data

# %%
data = dp.fetch_data()
# Out:
# Fetching data for TSLA...
# [*********************100%***********************]  1 of 1 completed
# Fetching data for BND...
# [*********************100%***********************]  1 of 1 completed
# Fetching data for SPY...
# [*********************100%***********************]  1 of 1 completed

# %% [markdown]
# Clean Data

# %%
cleaned_data = dp.clean_data()
# Out:
# ../scripts\data_preprocessing.py:32: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method='ffill', inplace=True)
# ../scripts\data_preprocessing.py:32: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method='ffill', inplace=True)
# ../scripts\data_preprocessing.py:32: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method='ffill', inplace=True)

# %% [markdown]
# Normalize Data

# %%
normalized_data = dp.normalize_data()

# %% [markdown]
# Visualize Data

# %%
dp.visualize_data()

# %% [markdown]
# Analyze Volatility

# %%
dp.analyze_volatility()

# %% [markdown]
# Decompose Trend and Seasonality

# %%
dp.decompose_trend_seasonality(ticker='TSLA')

# %% [markdown]
# Save processed data as csv

# %%
dp.save_processed_data()
# Out:
# Processed data for TSLA successfully saved to: ../data\TSLA_processed.csv
# Processed data for BND successfully saved to: ../data\BND_processed.csv
# Processed data for SPY successfully saved to: ../data\SPY_processed.csv
